# %% [markdown]
# ## Clustering Model: Model with Product Category
#
# Set up a basic pipeline using **standardized preprocessing from preprocess.py** and distilbert.
#
# ## 🔧 Steps:
# 1. Import Libraries and load data using **preprocess.py functions**
# 2. Preprocessing: refer data_preprocessing.ipynb notebook
# 3. Vectorization: TF-IDF Vectorization
# 4. Model: K-Means clustering on Product Name
# 5. Evaluation: Clustering
#
# ##  ✅ Purpose:
# Establish a working pipeline using **standardized preprocessing functions** and maintain baseline score (~70-80% accuracy expected).

# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import seaborn as sns
import re

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/bshanmugam/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/bshanmugam/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/bshanmugam/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ## Step 1: Load the Cleaned data

# %%
df = pd.read_csv('data/cleaned_amazon_reviews_final.csv')
print(df.head())
print(df.info())
# Out:
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# 0  Computers,Electronics Features,Tablets,Electro...       Electronics
# 1  Computers,Electronics Features,Tablets,Electro...       Electronics
# 2  Computers,Electronics Features,Tablets,Electro...       Electronics
# 3  Computers,Electronics Features,Tablets,Electro...       Electronics
# 4  Computers,Electronics Features,Tablets,Electro...       Electronics
#
#                                            imageURLs doRecommend  rating  \
# 0  https://pisces.bbystatic.com/image2/BestBuy_US...       False       3
# 1  https://pisces.bbystatic.com/image2/BestBuy_US...        True       5
# 2  https://pisces.bbystatic.com/image2/BestBuy_US...        True       4
# 3  https://pisces.bbystatic.com/image2/BestBuy_US...        True       5
# 4  https://pisces.bbystatic.com/image2/BestBuy_US...        True       5
#
#                                           sourceURLs  label  \
# 0  https://www.newegg.com/Product/Product.aspx%25...      1
# 1  https://www.newegg.com/Product/Product.aspx%25...      2
# 2  https://www.newegg.com/Product/Product.aspx%25...      2
# 3  https://www.newegg.com/Product/Product.aspx%25...      2
# 4  https://www.newegg.com/Product/Product.aspx%25...      2
#
#                                           clean_text
# 0  too small i thought it would be as big as smal...
# 1  great light reader easy to use at the beach th...
# 2  great for the price didnt know how much id use...
# 3  a great buy i am happy with my purchase i caug...
# 4  solid entrylevel kindle great for kids solid e...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20063 entries, 0 to 20062
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               20063 non-null  object
#  1   asins              20063 non-null  object
#  2   brand              20063 non-null  object
#  3   categories         20063 non-null  object
#  4   primaryCategories  20063 non-null  object
#  5   imageURLs          20063 non-null  object
#  6   doRecommend        10647 non-null  object
#  7   rating             20063 non-null  int64
#  8   sourceURLs         20063 non-null  object
#  9   label              20063 non-null  int64
#  10  clean_text         20063 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 1.7+ MB
# None

# %% [markdown]
# ## Step 2: Preprocess and Vectorize text using TF-IDF

# %%
	
name_vectorizer = TfidfVectorizer(stop_words='english')
product_names = df['name'].unique()
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(product_names)
print(f"TF-IDF Matrix Shape: {X.shape}")
# Out:
# TF-IDF Matrix Shape: (78, 238)

# %% [markdown]
# ## Step 3: K-Means Elbow Method

# %%
Cluster_labels = []  
k_values = range(2, 23) 

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    Cluster_labels.append(kmeans.inertia_)

plt.figure(figsize=(8, 5))
plt.plot(k_values, Cluster_labels, marker='o')
plt.title('Elbow Method for Optimal K')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Cluster_labels')
plt.show()

# %% [markdown]
# ## Step 4: K-Means Silhouette Score

# %%
silhouette_scores = []
valid_k = []
for k in k_values:
    if k == 1:
        continue  # Silhouette score is not defined for k=1
    kmeans = KMeans(n_clusters=k, random_state=42)
    cluster_labels = kmeans.fit_predict(X)
    silhouette_avg = silhouette_score(X, cluster_labels)
    silhouette_scores.append(silhouette_avg)
    valid_k.append(k)

plt.figure(figsize=(8, 5))
plt.plot(valid_k, silhouette_scores, marker='o')
plt.title('Silhouette Score for Optimal K')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Silhouette Score')
plt.show()

# %% [markdown]
#  ## Step 5: K-Means Clustering

# %%
kmeans = KMeans(n_clusters=23, random_state=42)
kmeans.fit(X)

# Attach cluster labels back to product names
product_clusters = pd.DataFrame({
    'product_name': product_names,
    'cluster': kmeans.labels_
})
# Step 4: View grouped products by cluster
for i in range(kmeans.n_clusters):
    print(f"\nCluster {i}:\n")
    print(product_clusters[product_clusters['cluster'] == i]['product_name'].tolist())
# Out:
# Cluster 0:
#
# ['AmazonBasics AAA Performance Alkaline Batteries (36 Count)', 'AmazonBasics AA Performance Alkaline Batteries (48 Count) - Packaging May Vary']
#
# Cluster 1:
#
# ['All-New Kindle Oasis E-reader - 7 High-Resolution Display (300 ppi), Waterproof, Built-In Audible, 32 GB, Wi-Fi + Free Cellular Connectivity', 'All-New Kindle Oasis E-reader - 7 High-Resolution Display (300 ppi), Waterproof, Built-In Audible, 8 GB, Wi-Fi - Includes Special Offers', 'All-New Kindle Oasis E-reader - 7 High-Resolution Display (300 ppi), Waterproof, Built-In Audible, 32 GB, Wi-Fi - Includes Special Offers']
#
# Cluster 2:
#
# ['Fire Tablet, 7 Display, Wi-Fi, 16 GB - Includes Special Offers, Black', 'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Blue', 'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 GB - Includes Special Offers, Blue', 'Fire HD 10 Tablet, 10.1 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Silver Aluminum', 'All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi, 16 GB - Includes Special Offers, Magenta', 'All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi, 32 GB - Includes Special Offers, Black', 'All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi, 32 GB - Includes Special Offers, Magenta', 'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Black', 'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 GB - Includes Special Offers, Magenta', 'All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 GB - Includes Special Offers, Black']
#
# Cluster 3:
#
# ['Amazon Kindle E-Reader 6" Wifi (8th Generation, 2016)', 'Amazon - Kindle Voyage - 6" - 4GB - Black', 'Amazon - Kindle Voyage - 4GB - Wi-Fi + 3G - Black']
#
# Cluster 4:
#
# ['Amazon 9W PowerFast Official OEM USB Charger and Power Adapter for Fire Tablets and Kindle eReaders', 'Amazon Kindle Charger Power Adapter Wall Charger And Usb Cable Micro Usb Cord', 'Oem Amazon Kindle Power Usb Adapter Wall Travel Charger Fire/dx/+micro Usb Cable', 'Amazon Kindle Replacement Power Adapter (Fits Latest Generation Kindle and Kindle DX) For shipment in the U.S only']
#
# Cluster 5:
#
# ['Amazon Echo Show Alexa-enabled Bluetooth Speaker with 7" Screen', 'Amazon - Echo Plus w/ Built-In Hub - Silver', 'Amazon Echo ‚Äì White', 'Amazon Echo Show - Black']
#
# Cluster 6:
#
# ['Fire HD 8 Tablet with Alexa, 8" HD Display, 32 GB, Tangerine - with Special Offers', 'Amazon Fire HD 8 with Alexa (8" HD Display Tablet)', 'All-New Fire HD 8 Tablet with Alexa, 8 HD Display, 32 GB, Marine Blue - with Special Offers', 'Fire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, Tangerine - with Special Offers']
#
# Cluster 7:
#
# ['Two Door Top Load Pet Kennel Travel Crate Dog Cat Pet Cage Carrier Box Tray 23"', 'AmazonBasics Single-Door Folding Metal Dog Crate - Large (42x28x30 Inches)', 'AmazonBasics Double-Door Folding Metal Dog Crate - Medium (36x23x25 Inches)']
#
# Cluster 8:
#
# ['Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Blue Kid-Proof Case', 'Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Green Kid-Proof Case', 'Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Pink Kid-Proof Case', 'All-New Fire HD 8 Kids Edition Tablet, 8 HD Display, 32 GB, Pink Kid-Proof Case', 'All-New Fire HD 8 Kids Edition Tablet, 8 HD Display, 32 GB, Blue Kid-Proof Case']
#
# Cluster 9:
#
# ['Kindle Oasis E-reader with Leather Charging Cover - Merlot, 6 High-Resolution Display (300 ppi), Wi-Fi - Includes Special Offers', 'Kindle Oasis E-reader with Leather Charging Cover - Black, 6" High-Resolution Display (300 ppi), Wi-Fi - Includes Special Offers', 'Kindle PowerFast International Charging Kit (for accelerated charging in over 200 countries)', 'AmazonBasics Silicone Hot Handle Cover/Holder - Red', 'Kindle Oasis E-reader with Leather Charging Cover - Black, 6 High-Resolution Display (300 ppi), Wi-Fi - Includes Special Offers', 'Kindle Oasis E-reader with Leather Charging Cover - Walnut, 6 High-Resolution Display (300 ppi), Wi-Fi - Includes Special Offers']
#
# Cluster 10:
#
# ['Echo Spot Pair Kit (Black)', 'Fire TV Stick Streaming Media Player Pair Kit', 'Amazon Fire TV Gaming Edition Streaming Media Player']
#
# Cluster 11:
#
# ['Amazon Fire TV with 4K Ultra HD and Alexa Voice Remote (Pendant Design) | Streaming Media Player', 'Amazon Tap - Alexa-Enabled Portable Bluetooth Speaker', 'Expanding Accordion File Folder Plastic Portable Document Organizer Letter Size', 'Certified Refurbished Amazon Echo', 'Certified Refurbished Amazon Fire TV with Alexa Voice Remote']
#
# Cluster 12:
#
# ['AmazonBasics Ventilated Adjustable Laptop Stand', 'AmazonBasics 11.6-Inch Laptop Sleeve', 'AmazonBasics 15.6-Inch Laptop and Tablet Bag']
#
# Cluster 13:
#
# ['AmazonBasics Nylon CD/DVD Binder (400 Capacity)', 'AmazonBasics Nespresso Pod Storage Drawer - 50 Capsule Capacity']
#
# Cluster 14:
#
# ['All-new Echo (2nd Generation) with improved sound, powered by Dolby, and a new design Walnut Finish']
#
# Cluster 15:
#
# ['Amazon Tap Smart Assistant Alexaenabled (black) Brand New', 'Amazon Echo (2nd Generation) Smart Assistant Oak Finish Priority Shipping', 'Echo Dot (Previous generation)']
#
# Cluster 16:
#
# ['Kindle E-reader - White, 6 Glare-Free Touchscreen Display, Wi-Fi - Includes Special Offers', 'Amazon Echo (1st Generationcertified) Color:White Free Shipping', 'All-New Kindle E-reader - Black, 6" Glare-Free Touchscreen Display, Wi-Fi - Includes Special Offers']
#
# Cluster 17:
#
# ['AmazonBasics USB 3.0 Cable - A-Male to B-Male - 6 Feet (1.8 Meters)', 'AmazonBasics 16-Gauge Speaker Wire - 100 Feet']
#
# Cluster 18:
#
# ['Cat Litter Box Covered Tray Kitten Extra Large Enclosed Hooded Hidden Toilet']
#
# Cluster 19:
#
# ['Kindle Voyage E-reader, 6 High-Resolution Display (300 ppi) with Adaptive Built-in Light, PagePress Sensors, Wi-Fi - Includes Special Offers', 'Kindle Voyage E-reader, 6 High-Resolution Display (300 ppi) with Adaptive Built-in Light, PagePress Sensors, Free 3G + Wi-Fi - Includes Special Offers']
#
# Cluster 20:
#
# ['AmazonBasics External Hard Drive Case']
#
# Cluster 21:
#
# ['Brand New Amazon Kindle Fire 16gb 7" Ips Display Tablet Wifi 16 Gb Blue', 'Fire Tablet with Alexa, 7" Display, 16 GB, Magenta - with Special Offers', 'All-New Fire 7 Tablet with Alexa, 7" Display, 8 GB - Marine Blue', 'All-New Fire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, Marine Blue - with Special Offers', 'Fire Tablet with Alexa, 7 Display, 16 GB, Magenta - with Special Offers', 'Fire Tablet with Alexa, 7 Display, 16 GB, Blue - with Special Offers']
#
# Cluster 22:
#
# ['AmazonBasics Backpack for Laptops up to 17-inches', 'AmazonBasics Bluetooth Keyboard for Android Devices - Black']

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
reduced = pca.fit_transform(X.toarray())

# Plot
plt.figure(figsize=(12, 8))
plt.scatter(reduced[:, 0], reduced[:, 1], c=kmeans.labels_, cmap='tab10', s=50)
for i, name in enumerate(product_names):
    plt.text(reduced[i, 0], reduced[i, 1], name[:15], fontsize=8)
plt.title('Product Clustering (PCA 2D View)')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.colorbar(label='Cluster ID')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

# Merge cluster assignments into df
df = df.merge(product_clusters, left_on='name', right_on='product_name', how='left')
df = df.rename(columns={'cluster': 'name_cluster'})

sns.countplot(x='name_cluster', data=df, palette='Set2')
plt.title('Number of Reviews per Product Name Cluster')
plt.xlabel('Name Cluster')
plt.ylabel('Review Count')
plt.show()
# Out:
# /var/folders/7j/c3cwb7d17c1cfkhmkrqtw4q00000gn/T/ipykernel_7115/4287335739.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='name_cluster', data=df, palette='Set2')

# %% [markdown]
# ## Step 6: Analyze Clusters

# %%
# Count the number of products in each cluster
cluster_counts = df['name_cluster'].value_counts().sort_index()
print(cluster_counts)

# Display sample products from each cluster
for cluster_id in range(kmeans.n_clusters):
    print(f"Cluster {cluster_id}:")
    print(df[df['name_cluster'] == cluster_id]['name'].sample(2))  

    print("\n")
# Out:
# name_cluster
# 0     9242
# 1       33
# 2     3549
# 3      198
# 4       61
# 5     1346
# 6      647
# 7        4
# 8     2206
# 9       78
# 10      11
# 11     250
# 12      39
# 13       5
# 14       2
# 15     391
# 16     249
# 17      11
# 18       2
# 19     456
# 20       6
# 21    1247
# 22      30
# Name: count, dtype: int64
# Cluster 0:
# 13465    AmazonBasics AA Performance Alkaline Batteries...
# 9155     AmazonBasics AAA Performance Alkaline Batterie...
# Name: name, dtype: object
#
#
# Cluster 1:
# 19496    All-New Kindle Oasis E-reader - 7 High-Resolut...
# 19518    All-New Kindle Oasis E-reader - 7 High-Resolut...
# Name: name, dtype: object
#
#
# Cluster 2:
# 17603    Fire Tablet, 7 Display, Wi-Fi, 16 GB - Include...
# 3408     All-New Fire HD 8 Tablet, 8" HD Display, Wi-Fi...
# Name: name, dtype: object
#
#
# Cluster 3:
# 4258    Amazon - Kindle Voyage - 4GB - Wi-Fi + 3G - Black
# 20      Amazon Kindle E-Reader 6" Wifi (8th Generation...
# Name: name, dtype: object
#
#
# Cluster 4:
# 13740    Amazon 9W PowerFast Official OEM USB Charger a...
# 13734    Amazon 9W PowerFast Official OEM USB Charger a...
# Name: name, dtype: object
#
#
# Cluster 5:
# 1095          Amazon - Echo Plus w/ Built-In Hub - Silver
# 537     Amazon Echo Show Alexa-enabled Bluetooth Speak...
# Name: name, dtype: object
#
#
# Cluster 6:
# 19074    All-New Fire HD 8 Tablet with Alexa, 8 HD Disp...
# 19839    Fire HD 8 Tablet with Alexa, 8 HD Display, 16 ...
# Name: name, dtype: object
#
#
# Cluster 7:
# 14185    Two Door Top Load Pet Kennel Travel Crate Dog ...
# 18067    AmazonBasics Double-Door Folding Metal Dog Cra...
# Name: name, dtype: object
#
#
# Cluster 8:
# 15261    Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16...
# 16805    Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16...
# Name: name, dtype: object
#
#
# Cluster 9:
# 4311    Kindle Oasis E-reader with Leather Charging Co...
# 4313    Kindle Oasis E-reader with Leather Charging Co...
# Name: name, dtype: object
#
#
# Cluster 10:
# 12152                       Echo Spot Pair Kit (Black)
# 12156    Fire TV Stick Streaming Media Player Pair Kit
# Name: name, dtype: object
#
#
# Cluster 11:
# 2785    Amazon Tap - Alexa-Enabled Portable Bluetooth ...
# 2920    Amazon Tap - Alexa-Enabled Portable Bluetooth ...
# Name: name, dtype: object
#
#
# Cluster 12:
# 13655    AmazonBasics Ventilated Adjustable Laptop Stand
# 13714       AmazonBasics 15.6-Inch Laptop and Tablet Bag
# Name: name, dtype: object
#
#
# Cluster 13:
# 14634    AmazonBasics Nespresso Pod Storage Drawer - 50...
# 12145      AmazonBasics Nylon CD/DVD Binder (400 Capacity)
# Name: name, dtype: object
#
#
# Cluster 14:
# 14642    All-new Echo (2nd Generation) with improved so...
# 14638    All-new Echo (2nd Generation) with improved so...
# Name: name, dtype: object
#
#
# Cluster 15:
# 13860    Amazon Tap Smart Assistant Alexaenabled (black...
# 14116    Amazon Tap Smart Assistant Alexaenabled (black...
# Name: name, dtype: object
#
#
# Cluster 16:
# 19686    Kindle E-reader - White, 6 Glare-Free Touchscr...
# 13781    Amazon Echo (1st Generationcertified) Color:Wh...
# Name: name, dtype: object
#
#
# Cluster 17:
# 14183    AmazonBasics USB 3.0 Cable - A-Male to B-Male ...
# 14190        AmazonBasics 16-Gauge Speaker Wire - 100 Feet
# Name: name, dtype: object
#
#
# Cluster 18:
# 13731    Cat Litter Box Covered Tray Kitten Extra Large...
# 13732    Cat Litter Box Covered Tray Kitten Extra Large...
# Name: name, dtype: object
#
#
# Cluster 19:
# 14277    Kindle Voyage E-reader, 6 High-Resolution Disp...
# 14540    Kindle Voyage E-reader, 6 High-Resolution Disp...
# Name: name, dtype: object
#
#
# Cluster 20:
# 13718    AmazonBasics External Hard Drive Case
# 13717    AmazonBasics External Hard Drive Case
# Name: name, dtype: object
#
#
# Cluster 21:
# 18250    All-New Fire HD 8 Tablet with Alexa, 8 HD Disp...
# 4206     Brand New Amazon Kindle Fire 16gb 7" Ips Displ...
# Name: name, dtype: object
#
#
# Cluster 22:
# 13673    AmazonBasics Backpack for Laptops up to 17-inches
# 13682    AmazonBasics Backpack for Laptops up to 17-inches
# Name: name, dtype: object

# %% [markdown]
# ## Step 7: Visualize Clusters

# %%
from sklearn.decomposition import PCA
import seaborn as sns

# Reduce dimensionality using PCA
pca = PCA(n_components=2)
tfidf_2d = pca.fit_transform(X.toarray())

# Create a DataFrame for PCA results with product names
pca_df = pd.DataFrame({
	'product_name': product_names,
	'pca_x': tfidf_2d[:, 0],
	'pca_y': tfidf_2d[:, 1]
})

# Merge PCA coordinates into the main df based on product name
df = df.merge(pca_df, left_on='name', right_on='product_name', how='left')

# Plot the clusters
plt.figure(figsize=(10, 8))
sns.scatterplot(x='pca_x', y='pca_y', hue='name_cluster', data=df, palette='viridis', s=100)
plt.title('2D PCA Visualization of Product Clusters')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[32], line 16
#       9 pca_df = pd.DataFrame({
#      10 	'product_name': product_names,
#      11 	'pca_x': tfidf_2d[:, 0],
#      12 	'pca_y': tfidf_2d[:, 1]
#      13 })
#      15 # Merge PCA coordinates into the main df based on product name
# ---> 16 df = df.merge(pca_df, left_on='name', right_on='product_name', how='left')
#      18 # Plot the clusters
#      19 plt.figure(figsize=(10, 8))
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:10832, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10813 @Substitution("")
#   10814 @Appender(_merge_doc, indents=2)
#   10815 def merge(
#    (...)
#   10828     validate: MergeValidate | None = None,
#   10829 ) -> DataFrame:
#   10830     from pandas.core.reshape.merge import merge
# > 10832     return merge(
#   10833         self,
#   10834         right,
#   10835         how=how,
#   10836         on=on,
#   10837         left_on=left_on,
#   10838         right_on=right_on,
#   10839         left_index=left_index,
#   10840         right_index=right_index,
#   10841         sort=sort,
#   10842         suffixes=suffixes,
#   10843         copy=copy,
#   10844         indicator=indicator,
#   10845         validate=validate,
#   10846     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/reshape/merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/reshape/merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/reshape/merge.py:840, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     837 left = self.left[:]
#     838 right = self.right[:]
# --> 840 llabels, rlabels = _items_overlap_with_suffix(
#     841     self.left._info_axis, self.right._info_axis, self.suffixes
#     842 )
#     844 if left_indexer is not None and not is_range_indexer(left_indexer, len(left)):
#     845     # Pinning the index here (and in the right code just below) is not
#     846     #  necessary, but makes the `.take` more performant if we have e.g.
#     847     #  a MultiIndex for left.index.
#     848     lmgr = left._mgr.reindex_indexer(
#     849         join_index,
#     850         left_indexer,
#    (...)
#     855         use_na_proxy=True,
#     856     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/reshape/merge.py:2757, in _items_overlap_with_suffix(left, right, suffixes)
#    2755     dups.extend(rlabels[(rlabels.duplicated()) & (~right.duplicated())].tolist())
#    2756 if dups:
# -> 2757     raise MergeError(
#    2758         f"Passing 'suffixes' which cause duplicate columns {set(dups)} is "
#    2759         f"not allowed.",
#    2760     )
#    2762 return llabels, rlabels
#
# MergeError: Passing 'suffixes' which cause duplicate columns {'product_name_x'} is not allowed.

# %% [markdown]
# ## Step 8: Identify 5 Best products

# %% [markdown]
# 5 Best products

# %%
sorted_df = df.sort_values(by=["rating", "text"], ascending=[False, False])
unique_best = sorted_df.drop_duplicates(subset="name", keep="first")
best_products = unique_best.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/7j/c3cwb7d17c1cfkhmkrqtw4q00000gn/T/ipykernel_7115/1040507354.py in ?()
# ----> 1 sorted_df = df.sort_values(by=["rating", "text"], ascending=[False, False])
#       2 unique_best = sorted_df.drop_duplicates(subset="name", keep="first")
#       3 best_products = unique_best.head(5)
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7168                 f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    7169                 f" != length of by ({len(by)})"
#    7170             )
#    7171         if len(by) > 1:
# -> 7172             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    7173
#    7174             # need to rewrap columns in Series to apply key function
#    7175             if key is not None:
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'text'

# %%
for _, row in best_products.iterrows():
    print(f"Image URL: {row['imageURLs']}")
    print(f"Product Name: {row['name']}")
    print(f"Review: {row['clean_text']}")
    print(f"Rating: {row['rating']}")
    print(f"Primary Categories: {row['primaryCategories']}")
    print("-" * 40)
    
def process_review(image_url, review, rating):
    print(f"Processing: {image_url}, {review}, {rating}")
# Out:
# Image URL: http://i.ebayimg.com/thumbs/images/g/3MIAAOSwol5Y4W6z/s-l96.jpg,https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5023/5023200_sa.jpg,http://i.ebayimg.com/thumbs/images/g/amcAAOSw6ShZSpke/s-l200.jpg,http://i.ebayimg.com/thumbs/images/g/PJgAAOSwiDFYPE8h/s-l200.jpg,http://i.ebayimg.com/thumbs/images/g/TPQAAOSwHb9Zcih6/s-l96.jpg,https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5023/5023200_sd.jpg,http://i.ebayimg.com/thumbs/images/g/J4EAAOSw4CFYnSS8/s-l200.jpg,http://i.ebayimg.com/thumbs/images/g
jpg,https://pisces.bbystatic.com/image2/BestBuy_US/exc/videometadata/thumbnail/442e05f98016eff1e4c910a71e19b33e.jpg,https://pisces.bbystatic.com/image2/BestBuy_US/exc/videometadata/thumbnail/a79225c6913eccf91c911facd476badf.jpg,https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5875/5875662cv15d.jpg,https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5875/5875662cv12d.jpg,https://c1.neweggimages.com/NeweggImage/ProductImage/81-511-002-V02.jpg,https://pisces.bbystatic.com/image2/BestBuy_US/exc/videometadata/thumbnail/c75967ea5140cb85217ef8346d8e7bbd.jpg,https://static.bhphoto.com/images/images500x500/amazon_b01j24c0ti_echo_show_black_1502460407000_1353418.jpg,https://static.bhphoto.com/images/images500x500/amazon_echo_show_2_pack_black_1506004002000_1353761.jpg,https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5875/5875662_sd.jpg,https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5875/5875662cv14d.jpg,https://c1.neweggimages.com/NeweggImage/ProductImage/81-511-002-Z01.jpg,https://www.barcodable.com/images/barcode/0841667120010.png,https://c1.neweggimages.com/NeweggImage/ProductImage/81-511-002-V03.jpg,https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5875/5875662cv11d.jpg,https://pisces.bbystatic.com/image2/BestBuy_US/images/products/5875/5875662cv16d.jpg,https://c1.neweggimages.com/NeweggImage/ProductImage/81-511-002-V01.jpg,https://images-na.ssl-images-amazon.com/images/I/51syqGPcCmL.jpg
# Product Name: Amazon Echo Show Alexa-enabled Bluetooth Speaker with 7" Screen
# Review: great abil echo line abl watch amazon prime even visual call grand daughter
# Rating: 5
# Primary Categories: Electronics,Hardware
# ----------------------------------------

# %% [markdown]
# Worst Product

# %%
from IPython.display import Image, display

worst_product = df.sort_values(by='label', ascending=True).head(1)

print("\nWorst Product:")
for index, row in worst_product.iterrows():
    #display(Image(url=url, width=100, height=100))
    print(f"Image URL: {row['imageURLs']}")
    print(f"Product Name: {row['name']}")
    print(f"Review: {row['clean_text']}")
    print(f"Rating: {row['rating']}")
    print(f"Primary Categories: {row['primaryCategories']}")
    print("-" * 40)

def process_review(image_url, review, rating):
    print(f"Processing: {image_url}, {review}, {rating}")
# Out:
# Worst Product:
# Image URL: https://static.bhphoto.com/images/images500x500/amazon_b010cehqtg_echo_show_white_1502460407000_1353417.jpg,https://c1.neweggimages.com/NeweggImage/ProductImage/81-511-001-V01.jpg,https://i5.walmartimages.com/asr/5638a5f1-ac87-4f19-a40a-1c8f97667060_1.eb5a3b378540fee9c3df5c656a718cd9.jpeg%252525253FodnHeight%252525253D450%2525252526odnWidth%252525253D450%2525252526odnBg%252525253DFFFFFF,https://i5.walmartimages.com/asr/db02a974-11af-4de9-b228-c36426eb2b44_1.22c5de2dd319a4ae3a2f23548c464eb1.jpeg%252525253FodnHeight%252525253D450%2525252526odnWidth%252525253D450%2525252526odnBg%252525253DFFFFFF,https://static.bhphoto.com/images/images500x500/amazon_echo_show_2_pack_white_1506004002000_1353763.jpg,https://www.barcodable.com/images/barcode/0848719084894.png,https://c1.neweggimages.com/NeweggImage/ProductImage/81-511-001-V02.jpg,https://c1.neweggimages.com/NeweggImage/ProductImage/81-511-001-Z01.jpg,https://images-na.ssl-images-amazon.com/images/I/51YHTHvHapL.jpg,https://c1.neweggimages.com/NeweggImage/ProductImage/81-511-001-V03.jpg,https://i5.walmartimages.com/asr/742c3b8b-69c9-45fc-80f7-cf24a98f26d0_1.425506278f53987c49795c9897a371e6.jpeg%252525253FodnHeight%252525253D450%2525252526odnWidth%252525253D450%2525252526odnBg%252525253DFFFFFF,https://i5.walmartimages.com/asr/a9577e52-7a76-48ec-b24d-9d7027dc93b8_1.6f920909d7d5977d1bf1af2b95b5dae3.jpeg%252525253FodnHeight%252525253D450%2525252526odnWidth%252525253D450%2525252526odnBg%252525253DFFFFFF
# Product Name: Amazon Echo Show Alexa-enabled Bluetooth Speaker with 7" Screen
# Review: qc bad qc realli bad product catch voic properli
# Rating: 1
# Primary Categories: Electronics,Hardware
# ----------------------------------------
